# %%
import numpy as np
import pygabor.timecausgabor
from importlib import reload

# %%
reload(pygabor.timecausgabor)
# Out:
# <module 'pygabor.timecausgabor' from '/Users/tony/Work/GitHub.com-mirror/pygabor/pygabor/timecausgabor.py'>

# %%
# Generate a temporal signal for testing purposes
from pygabor.discgabor import whitenoisesignal1D
testsignal = whitenoisesignal1D(1000)

# %%
# Use this function when computing the time-frequency transform at a single temporal scale
transform = pygabor.timecausgabor.timecausgabor(testsignal, 1, 5, 20)
print(transform)
# Out:
# (array([-9.24655364e-05, -3.23732956e-04, -7.12604496e-04, -1.26389505e-03,
#        -1.95681144e-03, -2.83742456e-03, -3.97165481e-03, -5.32533016e-03,
#        -6.79404716e-03, -8.34108128e-03, -1.00688514e-02, -1.20120725e-02,
#        -1.40994576e-02, -1.62057597e-02, -1.82220809e-02, -1.99957544e-02,
#        -2.13597301e-02, -2.21869032e-02, -2.24485250e-02, -2.22206637e-02,
#        -2.16433509e-02, -2.08615418e-02, -2.00503464e-02, -1.93772615e-02,
#        -1.88435131e-02, -1.83986381e-02, -1.80039412e-02, -1.77117115e-02,
#        -1.76205905e-02, -1.77679199e-02, -1.81504884e-02, -1.87316535e-02,
#        -1.93785224e-02, -1.99623518e-02, -2.03930275e-02, -2.06064311e-02,
#        -2.06368900e-02, -2.04875878e-02, -2.01072449e-02, -1.95364239e-02,
#        -1.87496618e-02, -1.77087006e-02, -1.63893146e-02, -1.48578263e-02,
#        -1.33204755e-02, -1.19947129e-02, -1.10028316e-02, -1.03320395e-02,
# ...

# %%
# Use this function when computing the time-frequency transform at multiple temporal scales
transforms = pygabor.timecausgabor.timecausgabor_mult(testsignal, 1, 5, 20, 80)
print(transforms)
# Out:
# (array([[-9.24655364e-05, -3.23732956e-04, -7.12604496e-04, ...,
#         -1.18533872e-02, -9.83355392e-03, -7.74235970e-03],
#        [-2.63100084e-06, -1.17675889e-05, -3.17090997e-05, ...,
#         -3.14026515e-02, -3.07889276e-02, -3.01331639e-02],
#        [-3.77021524e-08, -2.05791030e-07, -6.57232370e-07, ...,
#         -2.16489766e-02, -2.17799518e-02, -2.18996530e-02]]), array([[-3.12581133e-04, -1.09438412e-03, -2.40897019e-03, ...,
#         -4.00705533e-02, -3.32424766e-02, -2.61731632e-02],
#        [-8.89413783e-06, -3.97805108e-05, -1.07193087e-04, ...,
#         -1.06157135e-01, -1.04082432e-01, -1.01865613e-01],
#        [-1.27452692e-07, -6.95679664e-07, -2.22178389e-06, ...,
#         -7.31846903e-02, -7.36274539e-02, -7.40321057e-02]]), array([20., 40., 80.]))
