# %%
import numpy as np
import pygabor.discgabor
from importlib import reload

# %%
reload(pygabor.discgabor)
# Out:
# <module 'pygabor.discgabor' from '/Users/tony/Work/GitHub.com-mirror/pygabor/pygabor/discgabor.py'>

# %%
# Generate a synthetic signal for testing purpose
testsignal = pygabor.discgabor.whitenoisesignal1D(1000)

# %%
# Use this function when computing the time-frequency transform at a single temporal scale
transform = pygabor.discgabor.discgabor(testsignal, 1, 5, 20)
print(transform)
# Out:
# (array([-4.92457442e-02, -4.90889283e-02, -4.87757274e-02, -4.83070082e-02,
#        -4.76840733e-02, -4.69086547e-02, -4.59829256e-02, -4.49094944e-02,
#        -4.36914067e-02, -4.23321489e-02, -4.08356442e-02, -3.92062546e-02,
#        -3.74487783e-02, -3.55684477e-02, -3.35709257e-02, -3.14622953e-02,
#        -2.92490577e-02, -2.69381178e-02, -2.45367755e-02, -2.20527140e-02,
#        -1.94939750e-02, -1.68689519e-02, -1.41863580e-02, -1.14552100e-02,
#        -8.68479908e-03, -5.88466459e-03, -3.06456191e-03, -2.34431760e-04,
#         2.59563885e-03,  5.41545008e-03,  8.21473082e-03,  1.09831805e-02,
#         1.37105113e-02,  1.63864950e-02,  1.90010101e-02,  2.15440916e-02,
#         2.40059788e-02,  2.63771721e-02,  2.86484846e-02,  3.08110936e-02,
#         3.28565991e-02,  3.47770752e-02,  3.65651322e-02,  3.82139641e-02,
#         3.97174062e-02,  4.10699899e-02,  4.22669895e-02,  4.33044703e-02,
# ...

# %%
# Use this function when computing the time-frequency transform at multiple single temporal scales
transforms = pygabor.discgabor.discgabor_mult(testsignal, 1, 5, [20, 40, 80])
print(transform)
# Out:
# (array([-4.92457442e-02, -4.90889283e-02, -4.87757274e-02, -4.83070082e-02,
#        -4.76840733e-02, -4.69086547e-02, -4.59829256e-02, -4.49094944e-02,
#        -4.36914067e-02, -4.23321489e-02, -4.08356442e-02, -3.92062546e-02,
#        -3.74487783e-02, -3.55684477e-02, -3.35709257e-02, -3.14622953e-02,
#        -2.92490577e-02, -2.69381178e-02, -2.45367755e-02, -2.20527140e-02,
#        -1.94939750e-02, -1.68689519e-02, -1.41863580e-02, -1.14552100e-02,
#        -8.68479908e-03, -5.88466459e-03, -3.06456191e-03, -2.34431760e-04,
#         2.59563885e-03,  5.41545008e-03,  8.21473082e-03,  1.09831805e-02,
#         1.37105113e-02,  1.63864950e-02,  1.90010101e-02,  2.15440916e-02,
#         2.40059788e-02,  2.63771721e-02,  2.86484846e-02,  3.08110936e-02,
#         3.28565991e-02,  3.47770752e-02,  3.65651322e-02,  3.82139641e-02,
#         3.97174062e-02,  4.10699899e-02,  4.22669895e-02,  4.33044703e-02,
# ...
